# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import re

# %% [markdown]
# Import Data

# %%
df = pd.read_csv("../data/processed/CA_Fara_500_2019.csv")

# %% [markdown]
# List columns for copy and paste :)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'CountyName', 'GEOID', 'TotalPopulation',
#        'ACCESS2_CrudePrev', 'ACCESS2_Crude95CI', 'ARTHRITIS_CrudePrev',
#        'ARTHRITIS_Crude95CI', 'BINGE_CrudePrev', 'BINGE_Crude95CI',
#        'BPHIGH_CrudePrev', 'BPHIGH_Crude95CI', 'BPMED_CrudePrev',
#        'BPMED_Crude95CI', 'CANCER_CrudePrev', 'CANCER_Crude95CI',
#        'CASTHMA_CrudePrev', 'CASTHMA_Crude95CI', 'CERVICAL_CrudePrev',
#        'CERVICAL_Crude95CI', 'CHD_CrudePrev', 'CHD_Crude95CI',
#        'CHECKUP_CrudePrev', 'CHECKUP_Crude95CI', 'CHOLSCREEN_CrudePrev',
#        'CHOLSCREEN_Crude95CI', 'COLON_SCREEN_CrudePrev',
#        'COLON_SCREEN_Crude95CI', 'COPD_CrudePrev', 'COPD_Crude95CI',
#        'COREM_CrudePrev', 'COREM_Crude95CI', 'COREW_CrudePrev',
#        'COREW_Crude95CI', 'CSMOKING_CrudePrev', 'CSMOKING_Crude95CI',
#        'DENTAL_CrudePrev', 'DENTAL_Crude95CI', 'DEPRESSION_CrudePrev',
#        'DEPRESSION_Crude95CI', 'DIABETES_CrudePrev', 'DIABETES_Crude95CI',
#        'GHLTH_CrudePrev', 'GHLTH_Crude95CI', 'HIGHCHOL_CrudePrev',
#        'HIGHCHOL_Crude95CI', 'KIDNEY_CrudePrev', 'KIDNEY_Crude95CI',
#        'LPA_CrudePrev', 'LPA_Crude95CI', 'MAMMOUSE_CrudePrev',
#        'MAMMOUSE_Crude95CI', 'MHLTH_CrudePrev', 'MHLTH_Crude95CI',
#        'OBESITY_CrudePrev', 'OBESITY_Crude95CI', 'PHLTH_CrudePrev',
#        'PHLTH_Crude95CI', 'SLEEP_CrudePrev', 'SLEEP_Crude95CI',
#        'STROKE_CrudePrev', 'STROKE_Crude95CI', 'TEETHLOST_CrudePrev',
#        'TEETHLOST_Crude95CI', 'Geolocation', 'County', 'Urban', 'Pop2010',
#        'OHU2010', 'LILATracts_1And10', 'LILATracts_halfAnd10',
#        'LILATracts_1And20', 'LILATracts_Vehicle', 'HUNVFlag',
#        'LowIncomeTracts', 'PovertyRate', 'MedianFamilyIncome', 'LA1and10',
#        'LAhalfand10', 'LA1and20', 'LATracts_half', 'LATracts1', 'LATracts10',
#        'LATracts20', 'LATractsVehicle_20', 'LAPOP1_10', 'LAPOP05_10',
#        'LAPOP1_20', 'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'TractLOWI',
#        'Unnamed: 0', 'TotalPop', 'UninsuredPop', 'MedHouseInc'],
#       dtype='object')

# %% [markdown]
# Correlation matrix for Diabetes Crude Estimate and Low Access Indicators

# %%
df.loc[:, ["DIABETES_CrudePrev", "LATracts1", "LATracts10", "LATracts20"]].corr(method="kendall")
# Out:
#                     DIABETES_CrudePrev  LATracts1  LATracts10  LATracts20
# DIABETES_CrudePrev            1.000000  -0.105495    0.064192    0.030971
# LATracts1                    -0.105495   1.000000   -0.061488   -0.026085
# LATracts10                    0.064192  -0.061488    1.000000    0.424233
# LATracts20                    0.030971  -0.026085    0.424233    1.000000

# %% [markdown]
# Correlation and P value between Diabetes Crude Estimate and Uninsured Population + Check for any difference between Scipy Pearson and Pandas Pearson

# %%
corr, p_val = pearsonr(df["DIABETES_CrudePrev"], df["UninsuredPop"])
print(f'Correlation: {corr}, P-Value: {p_val}')
df[["DIABETES_CrudePrev", "UninsuredPop"]].corr(method='pearson')
# Out:
# Correlation: 0.0214465006979221, P-Value: 0.05503069267290367
#                     DIABETES_CrudePrev  UninsuredPop
# DIABETES_CrudePrev            1.000000      0.021447
# UninsuredPop                  0.021447      1.000000

# %% [markdown]
# From this we can conclude that the correlation observed is not statistically significant given the provided data (p-val > 0.05). <br>
# Additionally, we can now confidently interchange scipy and pandas pearson

# %% [markdown]
# Histogram of Diabetes Crude Estimate between Low Access Low Income Tracts and Not LALI Tracts

# %%
sns.histplot(data=df, x="DIABETES_CrudePrev", hue="LILATracts_1And10", common_norm=False, multiple="layer", kde=True, stat='percent')
# Out:
# <Axes: xlabel='DIABETES_CrudePrev', ylabel='Percent'>

# %% [markdown]
# Prep prune for large correlation matrix

# %%
d_cols = []
for i in df.columns:
    if re.match(string=i, pattern=r'\S*(CI)$'):
        d_cols.append(i)

d_cols.append("Unnamed: 0.1")
d_cols.append("Unnamed: 0")
d_cols.append("CountyName")
d_cols.append("County")
d_cols.append("Geolocation")
d_cols.append("GEOID")

d_cols
# Out:
# ['ACCESS2_Crude95CI',
#  'ARTHRITIS_Crude95CI',
#  'BINGE_Crude95CI',
#  'BPHIGH_Crude95CI',
#  'BPMED_Crude95CI',
#  'CANCER_Crude95CI',
#  'CASTHMA_Crude95CI',
#  'CERVICAL_Crude95CI',
#  'CHD_Crude95CI',
#  'CHECKUP_Crude95CI',
#  'CHOLSCREEN_Crude95CI',
#  'COLON_SCREEN_Crude95CI',
#  'COPD_Crude95CI',
#  'COREM_Crude95CI',
#  'COREW_Crude95CI',
#  'CSMOKING_Crude95CI',
#  'DENTAL_Crude95CI',
#  'DEPRESSION_Crude95CI',
#  'DIABETES_Crude95CI',
#  'GHLTH_Crude95CI',
#  'HIGHCHOL_Crude95CI',
#  'KIDNEY_Crude95CI',
#  'LPA_Crude95CI',
#  'MAMMOUSE_Crude95CI',
#  'MHLTH_Crude95CI',
#  'OBESITY_Crude95CI',
#  'PHLTH_Crude95CI',
#  'SLEEP_Crude95CI',
#  'STROKE_Crude95CI',
#  'TEETHLOST_Crude95CI',
#  'Unnamed: 0.1',
#  'Unnamed: 0',
#  'CountyName',
#  'County',
#  'Geolocation',
#  'GEOID']

# %%
corr_df = df.drop(columns=d_cols + ["TotalPopulation", "TotalPop"])

# %%
cols: list = corr_df.columns.to_list()
si = {}
while len(cols) != 0:
    ptr = cols[0]
    for i in cols[1:]:
        corr, p = pearsonr(corr_df[ptr], corr_df[i])
        if p <= 0.05 and abs(corr) >= 0.3:
            si[(ptr, i)] = (corr, p)
            print(f'"{ptr} & {i}"-- Correlation: {corr}, P-Value{p}')
    cols.pop(0)
# Out:
# "ACCESS2_CrudePrev & BPMED_CrudePrev"-- Correlation: -0.3548945917431337, P-Value3.0630672090682136e-236
# "ACCESS2_CrudePrev & CANCER_CrudePrev"-- Correlation: -0.6077554041881474, P-Value0.0
# "ACCESS2_CrudePrev & CASTHMA_CrudePrev"-- Correlation: 0.36597729634961607, P-Value3.2902931875342447e-252
# "ACCESS2_CrudePrev & CHECKUP_CrudePrev"-- Correlation: -0.6574959910224825, P-Value0.0
# "ACCESS2_CrudePrev & CHOLSCREEN_CrudePrev"-- Correlation: -0.7669418604728406, P-Value0.0
# "ACCESS2_CrudePrev & CSMOKING_CrudePrev"-- Correlation: 0.7099390846736333, P-Value0.0
# "ACCESS2_CrudePrev & DENTAL_CrudePrev"-- Correlation: -0.9210411315872522, P-Value0.0
# "ACCESS2_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.6610053959622753, P-Value0.0
# "ACCESS2_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.9348942156302119, P-Value0.0
# "ACCESS2_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.4873912535388115, P-Value0.0
# "ACCESS2_CrudePrev & LPA_CrudePrev"-- Correlation: 0.9240072006273459, P-Value0.0
# "ACCESS2_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.7536894998180168, P-Value0.0
# "ACCESS2_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.7307831024838976, P-Value0.0
# "ACCESS2_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.7601206504857327, P-Value0.0
# "ACCESS2_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.7635965534001873, P-Value0.0
# "ACCESS2_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.3001647669852035, P-Value2.5597636242271914e-166
# "ACCESS2_CrudePrev & OHU2010"-- Correlation: -0.3068534717904614, P-Value4.243466125017747e-174
# "ACCESS2_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.41206120740445407, P-Value0.0
# "ACCESS2_CrudePrev & LowIncomeTracts"-- Correlation: 0.6620048930741464, P-Value0.0
# "ACCESS2_CrudePrev & PovertyRate"-- Correlation: 0.6640445369392631, P-Value0.0
# "ACCESS2_CrudePrev & TractLOWI"-- Correlation: 0.6729177131076057, P-Value0.0
# "ARTHRITIS_CrudePrev & BINGE_CrudePrev"-- Correlation: -0.4071885179827238, P-Value2.173134e-317
# "ARTHRITIS_CrudePrev & BPHIGH_CrudePrev"-- Correlation: 0.8774136444937521, P-Value0.0
# "ARTHRITIS_CrudePrev & BPMED_CrudePrev"-- Correlation: 0.8047703565476083, P-Value0.0
# "ARTHRITIS_CrudePrev & CANCER_CrudePrev"-- Correlation: 0.8627164582729703, P-Value0.0
# "ARTHRITIS_CrudePrev & CASTHMA_CrudePrev"-- Correlation: 0.30590227890931293, P-Value5.581421616061323e-173
# "ARTHRITIS_CrudePrev & CHD_CrudePrev"-- Correlation: 0.8549765944142976, P-Value0.0
# "ARTHRITIS_CrudePrev & CHECKUP_CrudePrev"-- Correlation: 0.599696052973372, P-Value0.0
# "ARTHRITIS_CrudePrev & CHOLSCREEN_CrudePrev"-- Correlation: 0.4427779525483623, P-Value0.0
# "ARTHRITIS_CrudePrev & COPD_CrudePrev"-- Correlation: 0.7395589004884575, P-Value0.0
# "ARTHRITIS_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: 0.3442029861143151, P-Value1.9747254080663507e-221
# "ARTHRITIS_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.3862230899532461, P-Value4.652899228149206e-283
# "ARTHRITIS_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.8782666781921942, P-Value0.0
# "ARTHRITIS_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.6312629871986644, P-Value0.0
# "ARTHRITIS_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.32373509751521706, P-Value1.1569720104908859e-194
# "ARTHRITIS_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.31382198893200924, P-Value2.001768004946583e-182
# "ARTHRITIS_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.7437636947119298, P-Value0.0
# "ARTHRITIS_CrudePrev & Urban"-- Correlation: -0.311249207675524, P-Value2.5226843508174807e-179
# "BINGE_CrudePrev & BPHIGH_CrudePrev"-- Correlation: -0.638860275786501, P-Value0.0
# "BINGE_CrudePrev & BPMED_CrudePrev"-- Correlation: -0.5915527245682424, P-Value0.0
# "BINGE_CrudePrev & CHD_CrudePrev"-- Correlation: -0.5884689919189947, P-Value0.0
# "BINGE_CrudePrev & CHECKUP_CrudePrev"-- Correlation: -0.3961539245266701, P-Value5.202713097418143e-299
# "BINGE_CrudePrev & COPD_CrudePrev"-- Correlation: -0.397207464704863, P-Value9.806197167256116e-301
# "BINGE_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: 0.34989190764090927, P-Value3.0729346080774428e-229
# "BINGE_CrudePrev & DIABETES_CrudePrev"-- Correlation: -0.7079847176954166, P-Value0.0
# "BINGE_CrudePrev & GHLTH_CrudePrev"-- Correlation: -0.39836043616319516, P-Value1.2496320835538353e-302
# "BINGE_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: -0.5560483693902314, P-Value0.0
# "BINGE_CrudePrev & KIDNEY_CrudePrev"-- Correlation: -0.6538109727235312, P-Value0.0
# "BINGE_CrudePrev & LPA_CrudePrev"-- Correlation: -0.39257030339145127, P-Value3.435779018735792e-293
# "BINGE_CrudePrev & PHLTH_CrudePrev"-- Correlation: -0.41714611308585375, P-Value0.0
# "BINGE_CrudePrev & STROKE_CrudePrev"-- Correlation: -0.6225280299076172, P-Value0.0
# "BPHIGH_CrudePrev & BPMED_CrudePrev"-- Correlation: 0.7408007149551306, P-Value0.0
# "BPHIGH_CrudePrev & CANCER_CrudePrev"-- Correlation: 0.6133724596000671, P-Value0.0
# "BPHIGH_CrudePrev & CASTHMA_CrudePrev"-- Correlation: 0.3450964515034468, P-Value1.2022626829372456e-222
# "BPHIGH_CrudePrev & CHD_CrudePrev"-- Correlation: 0.9325825969206473, P-Value0.0
# "BPHIGH_CrudePrev & CHECKUP_CrudePrev"-- Correlation: 0.4562772498702907, P-Value0.0
# "BPHIGH_CrudePrev & COPD_CrudePrev"-- Correlation: 0.8236916370574239, P-Value0.0
# "BPHIGH_CrudePrev & CSMOKING_CrudePrev"-- Correlation: 0.33663019241728803, P-Value2.744040354584676e-211
# "BPHIGH_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.7272270379862581, P-Value0.0
# "BPHIGH_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.371546826779958, P-Value1.777099009087817e-260
# "BPHIGH_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.8103815695737557, P-Value0.0
# "BPHIGH_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.8652453395103128, P-Value0.0
# "BPHIGH_CrudePrev & LPA_CrudePrev"-- Correlation: 0.33869302861584916, P-Value5.053570264733767e-214
# "BPHIGH_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.39024640810693356, P-Value1.8686541554095633e-289
# "BPHIGH_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.5899969601501756, P-Value0.0
# "BPHIGH_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.9297003109594179, P-Value0.0
# "BPMED_CrudePrev & CANCER_CrudePrev"-- Correlation: 0.8017973414873334, P-Value0.0
# "BPMED_CrudePrev & CHD_CrudePrev"-- Correlation: 0.6583213876736201, P-Value0.0
# "BPMED_CrudePrev & CHECKUP_CrudePrev"-- Correlation: 0.7629017757410667, P-Value0.0
# "BPMED_CrudePrev & CHOLSCREEN_CrudePrev"-- Correlation: 0.6627934546946328, P-Value0.0
# "BPMED_CrudePrev & COPD_CrudePrev"-- Correlation: 0.4177605313528705, P-Value0.0
# "BPMED_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.3639550470325107, P-Value3.0108191973212816e-249
# "BPMED_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.8906764165515351, P-Value0.0
# "BPMED_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.48000437339073715, P-Value0.0
# "BPMED_CrudePrev & MHLTH_CrudePrev"-- Correlation: -0.4141924978180878, P-Value0.0
# "BPMED_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.34958791479406887, P-Value8.107800218286231e-229
# "BPMED_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.5767432272258148, P-Value0.0
# "CANCER_CrudePrev & CHD_CrudePrev"-- Correlation: 0.5891725230537029, P-Value0.0
# "CANCER_CrudePrev & CHECKUP_CrudePrev"-- Correlation: 0.8173684476759164, P-Value0.0
# "CANCER_CrudePrev & CHOLSCREEN_CrudePrev"-- Correlation: 0.7367812770441778, P-Value0.0
# "CANCER_CrudePrev & COPD_CrudePrev"-- Correlation: 0.3432686067700039, P-Value3.650958571409915e-220
# "CANCER_CrudePrev & CSMOKING_CrudePrev"-- Correlation: -0.37504708884840765, P-Value9.322683439736314e-266
# "CANCER_CrudePrev & DENTAL_CrudePrev"-- Correlation: 0.5667904681376904, P-Value0.0
# "CANCER_CrudePrev & GHLTH_CrudePrev"-- Correlation: -0.3947620647311838, P-Value9.664865434734417e-297
# "CANCER_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.8360173713185555, P-Value0.0
# "CANCER_CrudePrev & LPA_CrudePrev"-- Correlation: -0.44097250496557583, P-Value0.0
# "CANCER_CrudePrev & MHLTH_CrudePrev"-- Correlation: -0.5084638259768173, P-Value0.0
# "CANCER_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.6627449772545662, P-Value0.0
# "CANCER_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.40211341394166644, P-Value7.53209955104794e-309
# "CANCER_CrudePrev & LowIncomeTracts"-- Correlation: -0.37809009883397016, P-Value2.1171248381006664e-270
# "CANCER_CrudePrev & PovertyRate"-- Correlation: -0.39231070112828037, P-Value9.01189526353156e-293
# "CANCER_CrudePrev & TractLOWI"-- Correlation: -0.4282565541494482, P-Value0.0
# "CASTHMA_CrudePrev & CHD_CrudePrev"-- Correlation: 0.40000568799270597, P-Value2.398762352031644e-305
# "CASTHMA_CrudePrev & CHECKUP_CrudePrev"-- Correlation: -0.4087384078157561, P-Value5.004e-320
# "CASTHMA_CrudePrev & CHOLSCREEN_CrudePrev"-- Correlation: -0.5551221981255028, P-Value0.0
# "CASTHMA_CrudePrev & COPD_CrudePrev"-- Correlation: 0.6888186853879149, P-Value0.0
# "CASTHMA_CrudePrev & CSMOKING_CrudePrev"-- Correlation: 0.7946359223232424, P-Value0.0
# "CASTHMA_CrudePrev & DENTAL_CrudePrev"-- Correlation: -0.5406097318219624, P-Value0.0
# "CASTHMA_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: 0.8035320682213485, P-Value0.0
# "CASTHMA_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.39500976795275056, P-Value3.821178401041479e-297
# "CASTHMA_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.5374613942521569, P-Value0.0
# "CASTHMA_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.47602803280678013, P-Value0.0
# "CASTHMA_CrudePrev & LPA_CrudePrev"-- Correlation: 0.5548887775502975, P-Value0.0
# "CASTHMA_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.7925114455509754, P-Value0.0
# "CASTHMA_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.7273846686131571, P-Value0.0
# "CASTHMA_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.6973215850027287, P-Value0.0
# "CASTHMA_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.34228949580174056, P-Value7.678651631331654e-219
# "CASTHMA_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.5015097905317818, P-Value0.0
# "CASTHMA_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.41772694149658507, P-Value0.0
# "CASTHMA_CrudePrev & LowIncomeTracts"-- Correlation: 0.4834465351005103, P-Value0.0
# "CASTHMA_CrudePrev & PovertyRate"-- Correlation: 0.5849747482139661, P-Value0.0
# "CASTHMA_CrudePrev & LALOWI05_10"-- Correlation: 0.32529152362216107, P-Value1.2571030248667456e-196
# "CASTHMA_CrudePrev & TractLOWI"-- Correlation: 0.47995120803587865, P-Value0.0
# "CHD_CrudePrev & CHECKUP_CrudePrev"-- Correlation: 0.3342900326274809, P-Value3.2772832839985513e-208
# "CHD_CrudePrev & COPD_CrudePrev"-- Correlation: 0.9025679673353928, P-Value0.0
# "CHD_CrudePrev & CSMOKING_CrudePrev"-- Correlation: 0.40596943508511624, P-Value2.523643387e-315
# "CHD_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.7399204868709724, P-Value0.0
# "CHD_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.4474040008052331, P-Value0.0
# "CHD_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.7542376683627666, P-Value0.0
# "CHD_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.9076743954078674, P-Value0.0
# "CHD_CrudePrev & LPA_CrudePrev"-- Correlation: 0.409233581561642, P-Value7.134e-321
# "CHD_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.41890100026276006, P-Value0.0
# "CHD_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.6764934528431397, P-Value0.0
# "CHD_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.9440259202647587, P-Value0.0
# "CHD_CrudePrev & PovertyRate"-- Correlation: 0.3317275513831348, P-Value7.1489420759887535e-205
# "CHECKUP_CrudePrev & CHOLSCREEN_CrudePrev"-- Correlation: 0.8795846037243866, P-Value0.0
# "CHECKUP_CrudePrev & CSMOKING_CrudePrev"-- Correlation: -0.6059461262850826, P-Value0.0
# "CHECKUP_CrudePrev & DENTAL_CrudePrev"-- Correlation: 0.6338603643411936, P-Value0.0
# "CHECKUP_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: -0.36659374681752854, P-Value4.075848453060607e-253
# "CHECKUP_CrudePrev & GHLTH_CrudePrev"-- Correlation: -0.5025092297163383, P-Value0.0
# "CHECKUP_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.6715154724841861, P-Value0.0
# "CHECKUP_CrudePrev & LPA_CrudePrev"-- Correlation: -0.530682126558973, P-Value0.0
# "CHECKUP_CrudePrev & MHLTH_CrudePrev"-- Correlation: -0.7027419398262693, P-Value0.0
# "CHECKUP_CrudePrev & OBESITY_CrudePrev"-- Correlation: -0.46930142242983947, P-Value0.0
# "CHECKUP_CrudePrev & PHLTH_CrudePrev"-- Correlation: -0.3570167255139408, P-Value3.003024817115218e-239
# "CHECKUP_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.5409263487002736, P-Value0.0
# "CHECKUP_CrudePrev & LowIncomeTracts"-- Correlation: -0.46162003284066344, P-Value0.0
# "CHECKUP_CrudePrev & PovertyRate"-- Correlation: -0.4834689100113663, P-Value0.0
# "CHECKUP_CrudePrev & TractLOWI"-- Correlation: -0.5245522065423747, P-Value0.0
# "CHOLSCREEN_CrudePrev & CSMOKING_CrudePrev"-- Correlation: -0.7483108727491117, P-Value0.0
# "CHOLSCREEN_CrudePrev & DENTAL_CrudePrev"-- Correlation: 0.8025398876685236, P-Value0.0
# "CHOLSCREEN_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: -0.38137106833015055, P-Value1.831188379506077e-275
# "CHOLSCREEN_CrudePrev & GHLTH_CrudePrev"-- Correlation: -0.6924774724762012, P-Value0.0
# "CHOLSCREEN_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.5707643859330649, P-Value0.0
# "CHOLSCREEN_CrudePrev & LPA_CrudePrev"-- Correlation: -0.7369660298596794, P-Value0.0
# "CHOLSCREEN_CrudePrev & MHLTH_CrudePrev"-- Correlation: -0.870628161181747, P-Value0.0
# "CHOLSCREEN_CrudePrev & OBESITY_CrudePrev"-- Correlation: -0.5824713386287486, P-Value0.0
# "CHOLSCREEN_CrudePrev & PHLTH_CrudePrev"-- Correlation: -0.5763307354112867, P-Value0.0
# "CHOLSCREEN_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.6424303068861128, P-Value0.0
# "CHOLSCREEN_CrudePrev & LILATracts_halfAnd10"-- Correlation: -0.4224439662841025, P-Value0.0
# "CHOLSCREEN_CrudePrev & LowIncomeTracts"-- Correlation: -0.6253751122395774, P-Value0.0
# "CHOLSCREEN_CrudePrev & PovertyRate"-- Correlation: -0.7115622833053327, P-Value0.0
# "CHOLSCREEN_CrudePrev & TractLOWI"-- Correlation: -0.650174926292717, P-Value0.0
# "COPD_CrudePrev & CSMOKING_CrudePrev"-- Correlation: 0.7043520562430761, P-Value0.0
# "COPD_CrudePrev & DENTAL_CrudePrev"-- Correlation: -0.4691550983826382, P-Value0.0
# "COPD_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: 0.5886278424721763, P-Value0.0
# "COPD_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.7155518944178806, P-Value0.0
# "COPD_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.5832842338008366, P-Value0.0
# "COPD_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.5406155765920244, P-Value0.0
# "COPD_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.8554496128517621, P-Value0.0
# "COPD_CrudePrev & LPA_CrudePrev"-- Correlation: 0.5671758142656498, P-Value0.0
# "COPD_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.5569955997993095, P-Value0.0
# "COPD_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.6290866079198772, P-Value0.0
# "COPD_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.8260162989168099, P-Value0.0
# "COPD_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.9025590915372707, P-Value0.0
# "COPD_CrudePrev & Urban"-- Correlation: -0.30589334545074903, P-Value5.7178756199562654e-173
# "COPD_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.3396194075616744, P-Value2.941875006105017e-215
# "COPD_CrudePrev & LowIncomeTracts"-- Correlation: 0.42381544727727705, P-Value0.0
# "COPD_CrudePrev & PovertyRate"-- Correlation: 0.5088679130948812, P-Value0.0
# "COPD_CrudePrev & TractLOWI"-- Correlation: 0.3396747371405288, P-Value2.481583757585888e-215
# "CSMOKING_CrudePrev & DENTAL_CrudePrev"-- Correlation: -0.8507653825592338, P-Value0.0
# "CSMOKING_CrudePrev & DEPRESSION_CrudePrev"-- Correlation: 0.5929548892023849, P-Value0.0
# "CSMOKING_CrudePrev & DIABETES_CrudePrev"-- Correlation: 0.6376615108905681, P-Value0.0
# "CSMOKING_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.8366259653836312, P-Value0.0
# "CSMOKING_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.5758736516091426, P-Value0.0
# "CSMOKING_CrudePrev & LPA_CrudePrev"-- Correlation: 0.8552595275798931, P-Value0.0
# "CSMOKING_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.9238284165309916, P-Value0.0
# "CSMOKING_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.8408466627040986, P-Value0.0
# "CSMOKING_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.8889540389934454, P-Value0.0
# "CSMOKING_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.6978654743140377, P-Value0.0
# "CSMOKING_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.5438628553900604, P-Value0.0
# "CSMOKING_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.4749329071898028, P-Value0.0
# "CSMOKING_CrudePrev & LowIncomeTracts"-- Correlation: 0.6526188901206942, P-Value0.0
# "CSMOKING_CrudePrev & PovertyRate"-- Correlation: 0.7374829268108664, P-Value0.0
# "CSMOKING_CrudePrev & LALOWI05_10"-- Correlation: 0.344948941739251, P-Value1.9096469786714497e-222
# "CSMOKING_CrudePrev & TractLOWI"-- Correlation: 0.6409207245771464, P-Value0.0
# "DENTAL_CrudePrev & DIABETES_CrudePrev"-- Correlation: -0.7180200813909996, P-Value0.0
# "DENTAL_CrudePrev & GHLTH_CrudePrev"-- Correlation: -0.9449294149227466, P-Value0.0
# "DENTAL_CrudePrev & KIDNEY_CrudePrev"-- Correlation: -0.5741550415055798, P-Value0.0
# "DENTAL_CrudePrev & LPA_CrudePrev"-- Correlation: -0.953455748550479, P-Value0.0
# "DENTAL_CrudePrev & MHLTH_CrudePrev"-- Correlation: -0.862736999295197, P-Value0.0
# "DENTAL_CrudePrev & OBESITY_CrudePrev"-- Correlation: -0.7725221712262518, P-Value0.0
# "DENTAL_CrudePrev & PHLTH_CrudePrev"-- Correlation: -0.8468912499306174, P-Value0.0
# "DENTAL_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.8292298375417334, P-Value0.0
# "DENTAL_CrudePrev & STROKE_CrudePrev"-- Correlation: -0.4534251718440083, P-Value0.0
# "DENTAL_CrudePrev & LILATracts_halfAnd10"-- Correlation: -0.493521224625068, P-Value0.0
# "DENTAL_CrudePrev & LowIncomeTracts"-- Correlation: -0.7585569723377626, P-Value0.0
# "DENTAL_CrudePrev & PovertyRate"-- Correlation: -0.8064706743529583, P-Value0.0
# "DENTAL_CrudePrev & LALOWI05_10"-- Correlation: -0.3063185418138713, P-Value1.809465197851554e-173
# "DENTAL_CrudePrev & TractLOWI"-- Correlation: -0.7098480301418885, P-Value0.0
# "DEPRESSION_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.6278736081646756, P-Value0.0
# "DEPRESSION_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.5269981860638877, P-Value0.0
# "DEPRESSION_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.46489479662289535, P-Value0.0
# "DEPRESSION_CrudePrev & PovertyRate"-- Correlation: 0.3559946930121237, P-Value8.499673294167266e-238
# "DIABETES_CrudePrev & GHLTH_CrudePrev"-- Correlation: 0.8429646854892363, P-Value0.0
# "DIABETES_CrudePrev & HIGHCHOL_CrudePrev"-- Correlation: 0.40807548090976375, P-Value6.74953e-319
# "DIABETES_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.9190580268322968, P-Value0.0
# "DIABETES_CrudePrev & LPA_CrudePrev"-- Correlation: 0.8236594369793793, P-Value0.0
# "DIABETES_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.5036490400769572, P-Value0.0
# "DIABETES_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.6484250446330719, P-Value0.0
# "DIABETES_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.865333531667378, P-Value0.0
# "DIABETES_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.5499149164771862, P-Value0.0
# "DIABETES_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.852847784372281, P-Value0.0
# "DIABETES_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.3705736329426333, P-Value5.083672514403169e-259
# "DIABETES_CrudePrev & LowIncomeTracts"-- Correlation: 0.5533688823217192, P-Value0.0
# "DIABETES_CrudePrev & PovertyRate"-- Correlation: 0.5792160559850612, P-Value0.0
# "DIABETES_CrudePrev & TractLOWI"-- Correlation: 0.4700563958220175, P-Value0.0
# "GHLTH_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.7308142766040565, P-Value0.0
# "GHLTH_CrudePrev & LPA_CrudePrev"-- Correlation: 0.9822592055825297, P-Value0.0
# "GHLTH_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.8162089756678267, P-Value0.0
# "GHLTH_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.8322980948145418, P-Value0.0
# "GHLTH_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.933262814828494, P-Value0.0
# "GHLTH_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.7549551723482443, P-Value0.0
# "GHLTH_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.5931386966505, P-Value0.0
# "GHLTH_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.4639434274177982, P-Value0.0
# "GHLTH_CrudePrev & LowIncomeTracts"-- Correlation: 0.7076539727775961, P-Value0.0
# "GHLTH_CrudePrev & PovertyRate"-- Correlation: 0.7574109819882571, P-Value0.0
# "GHLTH_CrudePrev & TractLOWI"-- Correlation: 0.677282496631322, P-Value0.0
# "HIGHCHOL_CrudePrev & KIDNEY_CrudePrev"-- Correlation: 0.54494847686011, P-Value0.0
# "HIGHCHOL_CrudePrev & MHLTH_CrudePrev"-- Correlation: -0.30798918200808906, P-Value1.9325721057985428e-175
# "HIGHCHOL_CrudePrev & SLEEP_CrudePrev"-- Correlation: -0.33055365671088344, P-Value2.3607951475995906e-203
# "HIGHCHOL_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.6185124030047147, P-Value0.0
# "KIDNEY_CrudePrev & LPA_CrudePrev"-- Correlation: 0.6879266387532132, P-Value0.0
# "KIDNEY_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.46431223118630605, P-Value0.0
# "KIDNEY_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.636827395807638, P-Value0.0
# "KIDNEY_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.853053350845421, P-Value0.0
# "KIDNEY_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.34165474963016784, P-Value5.499727878212519e-218
# "KIDNEY_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.9589636780720452, P-Value0.0
# "KIDNEY_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.33941740978726853, P-Value5.473602100461502e-215
# "KIDNEY_CrudePrev & LowIncomeTracts"-- Correlation: 0.4801444788846248, P-Value0.0
# "KIDNEY_CrudePrev & PovertyRate"-- Correlation: 0.5451662371219452, P-Value0.0
# "KIDNEY_CrudePrev & TractLOWI"-- Correlation: 0.3790741979700146, P-Value6.505303204852893e-272
# "LPA_CrudePrev & MHLTH_CrudePrev"-- Correlation: 0.8318425332358959, P-Value0.0
# "LPA_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.8065562479909589, P-Value0.0
# "LPA_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.9122336139874812, P-Value0.0
# "LPA_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.7728397714622941, P-Value0.0
# "LPA_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.5624206107900481, P-Value0.0
# "LPA_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.4897948515320595, P-Value0.0
# "LPA_CrudePrev & LowIncomeTracts"-- Correlation: 0.7229279048261088, P-Value0.0
# "LPA_CrudePrev & PovertyRate"-- Correlation: 0.7604111425904788, P-Value0.0
# "LPA_CrudePrev & LALOWI05_10"-- Correlation: 0.3292081161457904, P-Value1.2756367623235215e-201
# "LPA_CrudePrev & TractLOWI"-- Correlation: 0.7065472460726374, P-Value0.0
# "MHLTH_CrudePrev & OBESITY_CrudePrev"-- Correlation: 0.808111827459927, P-Value0.0
# "MHLTH_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.8191913973961333, P-Value0.0
# "MHLTH_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.6993283121022449, P-Value0.0
# "MHLTH_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.3867163616085876, P-Value7.733006429380328e-284
# "MHLTH_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.49357251588085044, P-Value0.0
# "MHLTH_CrudePrev & LowIncomeTracts"-- Correlation: 0.6879027677413425, P-Value0.0
# "MHLTH_CrudePrev & PovertyRate"-- Correlation: 0.8122941054120948, P-Value0.0
# "MHLTH_CrudePrev & LALOWI05_10"-- Correlation: 0.3539252919715806, P-Value7.123271764454252e-235
# "MHLTH_CrudePrev & TractLOWI"-- Correlation: 0.6824564311039436, P-Value0.0
# "OBESITY_CrudePrev & PHLTH_CrudePrev"-- Correlation: 0.8656734857714826, P-Value0.0
# "OBESITY_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.6651232415870145, P-Value0.0
# "OBESITY_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.5420548931632008, P-Value0.0
# "OBESITY_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.43707048238153207, P-Value0.0
# "OBESITY_CrudePrev & LowIncomeTracts"-- Correlation: 0.5689606473134216, P-Value0.0
# "OBESITY_CrudePrev & PovertyRate"-- Correlation: 0.6289741429078067, P-Value0.0
# "OBESITY_CrudePrev & LALOWI05_10"-- Correlation: 0.3534332758987082, P-Value3.503395670713036e-234
# "OBESITY_CrudePrev & TractLOWI"-- Correlation: 0.5828217222962527, P-Value0.0
# "PHLTH_CrudePrev & SLEEP_CrudePrev"-- Correlation: 0.6138641569177343, P-Value0.0
# "PHLTH_CrudePrev & STROKE_CrudePrev"-- Correlation: 0.7749657598880129, P-Value0.0
# "PHLTH_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.4672221956902604, P-Value0.0
# "PHLTH_CrudePrev & LowIncomeTracts"-- Correlation: 0.6643943051885585, P-Value0.0
# "PHLTH_CrudePrev & PovertyRate"-- Correlation: 0.7483952140793676, P-Value0.0
# "PHLTH_CrudePrev & LALOWI05_10"-- Correlation: 0.3036691083753373, P-Value2.2778508828541684e-170
# "PHLTH_CrudePrev & TractLOWI"-- Correlation: 0.6174903799111277, P-Value0.0
# "SLEEP_CrudePrev & LILATracts_halfAnd10"-- Correlation: 0.38834272012848897, P-Value2.037780660477644e-286
# "SLEEP_CrudePrev & LowIncomeTracts"-- Correlation: 0.5866776638864708, P-Value0.0
# "SLEEP_CrudePrev & PovertyRate"-- Correlation: 0.6319980346118388, P-Value0.0
# "SLEEP_CrudePrev & TractLOWI"-- Correlation: 0.5747756177681351, P-Value0.0
# "STROKE_CrudePrev & LowIncomeTracts"-- Correlation: 0.3971790078780776, P-Value1.0918659650788361e-300
# "STROKE_CrudePrev & PovertyRate"-- Correlation: 0.45743577907092414, P-Value0.0
# "Urban & LAhalfand10"-- Correlation: 0.35882950509284767, P-Value7.74819787425913e-242
# "Urban & LATracts_half"-- Correlation: 0.4431180285143985, P-Value0.0
# "Urban & LATracts10"-- Correlation: -0.3711615696916093, P-Value6.712478975549536e-260
# "Pop2010 & OHU2010"-- Correlation: 0.797460623633735, P-Value0.0
# "Pop2010 & LAPOP1_10"-- Correlation: 0.32495737660734686, P-Value3.326507161856877e-196
# "Pop2010 & LAPOP05_10"-- Correlation: 0.5234690167817628, P-Value0.0
# "Pop2010 & LAPOP1_20"-- Correlation: 0.328740517355682, P-Value5.079326287309017e-201
# "Pop2010 & LALOWI05_10"-- Correlation: 0.38611407688783694, P-Value6.914878633969928e-283
# "Pop2010 & TractLOWI"-- Correlation: 0.5408003689602396, P-Value0.0
# "Pop2010 & UninsuredPop"-- Correlation: 0.687682692330684, P-Value0.0
# "OHU2010 & LAPOP05_10"-- Correlation: 0.3991482962269645, P-Value6.276506068128724e-304
# "OHU2010 & UninsuredPop"-- Correlation: 0.4748488878218379, P-Value0.0
# "LILATracts_1And10 & LILATracts_halfAnd10"-- Correlation: 0.4464488722703506, P-Value0.0
# "LILATracts_1And10 & LILATracts_1And20"-- Correlation: 0.9603577489715951, P-Value0.0
# "LILATracts_1And10 & LowIncomeTracts"-- Correlation: 0.3068653712689603, P-Value4.10861238878796e-174
# "LILATracts_1And10 & LA1and10"-- Correlation: 0.4707757378102808, P-Value0.0
# "LILATracts_1And10 & LA1and20"-- Correlation: 0.43797776489851714, P-Value0.0
# "LILATracts_1And10 & LATracts1"-- Correlation: 0.42428310595317115, P-Value0.0
# "LILATracts_1And10 & LAPOP1_10"-- Correlation: 0.31043529405040277, P-Value2.3782893462877045e-178
# "LILATracts_1And10 & LALOWI1_10"-- Correlation: 0.5575227815052515, P-Value0.0
# "LILATracts_1And10 & LALOWI05_10"-- Correlation: 0.4524393148838952, P-Value0.0
# "LILATracts_1And10 & LALOWI1_20"-- Correlation: 0.533393284044408, P-Value0.0
# "LILATracts_halfAnd10 & LILATracts_1And20"-- Correlation: 0.428750634004461, P-Value0.0
# "LILATracts_halfAnd10 & LILATracts_Vehicle"-- Correlation: 0.38460560189471915, P-Value1.6367072511055429e-280
# "LILATracts_halfAnd10 & LowIncomeTracts"-- Correlation: 0.6873471752956645, P-Value0.0
# "LILATracts_halfAnd10 & PovertyRate"-- Correlation: 0.4499083124139096, P-Value0.0
# "LILATracts_halfAnd10 & LAhalfand10"-- Correlation: 0.3962840751564731, P-Value3.1878877384084967e-299
# "LILATracts_halfAnd10 & LATracts_half"-- Correlation: 0.37561997444213785, P-Value1.256302304479106e-266
# "LILATracts_halfAnd10 & LALOWI05_10"-- Correlation: 0.5469510963699167, P-Value0.0
# "LILATracts_halfAnd10 & TractLOWI"-- Correlation: 0.45745541962039704, P-Value0.0
# "LILATracts_1And20 & LA1and10"-- Correlation: 0.452113127833923, P-Value0.0
# "LILATracts_1And20 & LA1and20"-- Correlation: 0.46486211119951915, P-Value0.0
# "LILATracts_1And20 & LATracts1"-- Correlation: 0.4506061430503049, P-Value0.0
# "LILATracts_1And20 & LAPOP1_10"-- Correlation: 0.3140666235062529, P-Value1.0115579978165345e-182
# "LILATracts_1And20 & LAPOP1_20"-- Correlation: 0.31235437588356607, P-Value1.1852895044486464e-180
# "LILATracts_1And20 & LALOWI1_10"-- Correlation: 0.558121482378636, P-Value0.0
# "LILATracts_1And20 & LALOWI05_10"-- Correlation: 0.4698911087346412, P-Value0.0
# "LILATracts_1And20 & LALOWI1_20"-- Correlation: 0.5586534728207998, P-Value0.0
# "LILATracts_Vehicle & HUNVFlag"-- Correlation: 0.7821321442938153, P-Value0.0
# "LILATracts_Vehicle & LATractsVehicle_20"-- Correlation: 0.7939930117600125, P-Value0.0
# "LILATracts_Vehicle & LALOWI05_10"-- Correlation: 0.4108117496703128, P-Value1e-323
# "HUNVFlag & LATractsVehicle_20"-- Correlation: 0.9884767744655012, P-Value0.0
# "HUNVFlag & LALOWI05_10"-- Correlation: 0.38370907407472754, P-Value4.159980530789715e-279
# "LowIncomeTracts & PovertyRate"-- Correlation: 0.6976546964596633, P-Value0.0
# "LowIncomeTracts & TractLOWI"-- Correlation: 0.5981664238045773, P-Value0.0
# "PovertyRate & TractLOWI"-- Correlation: 0.6299251012935696, P-Value0.0
# "LA1and10 & LAhalfand10"-- Correlation: 0.3758064918026936, P-Value6.536087982769066e-267
# "LA1and10 & LA1and20"-- Correlation: 0.9725746989086737, P-Value0.0
# "LA1and10 & LATracts_half"-- Correlation: 0.3249282173333477, P-Value3.6211180212428313e-196
# "LA1and10 & LATracts1"-- Correlation: 0.9664746514742573, P-Value0.0
# "LA1and10 & LAPOP1_10"-- Correlation: 0.7457983162349003, P-Value0.0
# "LA1and10 & LAPOP05_10"-- Correlation: 0.6192918665484822, P-Value0.0
# "LA1and10 & LAPOP1_20"-- Correlation: 0.7306588225043618, P-Value0.0
# "LA1and10 & LALOWI1_10"-- Correlation: 0.5964945811828939, P-Value0.0
# "LA1and10 & LALOWI05_10"-- Correlation: 0.3620396428359002, P-Value1.8363611215328966e-246
# "LA1and10 & LALOWI1_20"-- Correlation: 0.5805717991567094, P-Value0.0
# "LAhalfand10 & LA1and20"-- Correlation: 0.3654998856129297, P-Value1.6531163900005988e-251
# "LAhalfand10 & LATracts_half"-- Correlation: 0.9715126320194125, P-Value0.0
# "LAhalfand10 & LATracts1"-- Correlation: 0.3632074481867714, P-Value3.698942216112405e-248
# "LAhalfand10 & LAPOP05_10"-- Correlation: 0.6361818930265282, P-Value0.0
# "LAhalfand10 & LALOWI05_10"-- Correlation: 0.495530347481598, P-Value0.0
# "LA1and20 & LATracts_half"-- Correlation: 0.3647987075243919, P-Value1.7611799261693884e-250
# "LA1and20 & LATracts1"-- Correlation: 0.9937279394155926, P-Value0.0
# "LA1and20 & LAPOP1_10"-- Correlation: 0.7437078232609576, P-Value0.0
# "LA1and20 & LAPOP05_10"-- Correlation: 0.6365247733039414, P-Value0.0
# "LA1and20 & LAPOP1_20"-- Correlation: 0.7508068817849903, P-Value0.0
# "LA1and20 & LALOWI1_10"-- Correlation: 0.5859839561359578, P-Value0.0
# "LA1and20 & LALOWI05_10"-- Correlation: 0.3708197936754081, P-Value2.178978121770236e-259
# "LA1and20 & LALOWI1_20"-- Correlation: 0.5961961730585607, P-Value0.0
# "LATracts_half & LATracts1"-- Correlation: 0.3738576691810983, P-Value5.903837329172922e-264
# "LATracts_half & LAPOP05_10"-- Correlation: 0.6358174586759996, P-Value0.0
# "LATracts_half & LALOWI05_10"-- Correlation: 0.49033601430479834, P-Value0.0
# "LATracts1 & LAPOP1_10"-- Correlation: 0.7391280002253563, P-Value0.0
# "LATracts1 & LAPOP05_10"-- Correlation: 0.6377013126348741, P-Value0.0
# "LATracts1 & LAPOP1_20"-- Correlation: 0.7514702680674051, P-Value0.0
# "LATracts1 & LALOWI1_10"-- Correlation: 0.5763145789378015, P-Value0.0
# "LATracts1 & LALOWI05_10"-- Correlation: 0.3687982284150133, P-Value2.2401460728696049e-256
# "LATracts1 & LALOWI1_20"-- Correlation: 0.5945487916676702, P-Value0.0
# "LATracts10 & LATracts20"-- Correlation: 0.4242334799243175, P-Value0.0
# "LATractsVehicle_20 & LALOWI05_10"-- Correlation: 0.3861829180928925, P-Value5.384390863082839e-283
# "LAPOP1_10 & LAPOP05_10"-- Correlation: 0.7154436490601113, P-Value0.0
# "LAPOP1_10 & LAPOP1_20"-- Correlation: 0.9894610242783152, P-Value0.0
# "LAPOP1_10 & LALOWI1_10"-- Correlation: 0.8030877983864491, P-Value0.0
# "LAPOP1_10 & LALOWI05_10"-- Correlation: 0.4337587740816582, P-Value0.0
# "LAPOP1_10 & LALOWI1_20"-- Correlation: 0.796928473640589, P-Value0.0
# "LAPOP05_10 & LAPOP1_20"-- Correlation: 0.7183794190761789, P-Value0.0
# "LAPOP05_10 & LALOWI1_10"-- Correlation: 0.5687393579093082, P-Value0.0
# "LAPOP05_10 & LALOWI05_10"-- Correlation: 0.7276911015666991, P-Value0.0
# "LAPOP05_10 & LALOWI1_20"-- Correlation: 0.5772872324822328, P-Value0.0
# "LAPOP05_10 & UninsuredPop"-- Correlation: 0.3428399250001173, P-Value1.3873539745943683e-219
# "LAPOP1_20 & LALOWI1_10"-- Correlation: 0.7874599163781058, P-Value0.0
# "LAPOP1_20 & LALOWI05_10"-- Correlation: 0.433159229144514, P-Value0.0
# "LAPOP1_20 & LALOWI1_20"-- Correlation: 0.8042940472902227, P-Value0.0
# "LALOWI1_10 & LALOWI05_10"-- Correlation: 0.621577908885723, P-Value0.0
# "LALOWI1_10 & LALOWI1_20"-- Correlation: 0.982965168043999, P-Value0.0
# "LALOWI05_10 & LALOWI1_20"-- Correlation: 0.6234326667556487, P-Value0.0
# "LALOWI05_10 & TractLOWI"-- Correlation: 0.510478909021552, P-Value0.0
# "LALOWI05_10 & UninsuredPop"-- Correlation: 0.3623155907370156, P-Value7.309185481109667e-247
# "TractLOWI & UninsuredPop"-- Correlation: 0.5699322727582637, P-Value0.0
